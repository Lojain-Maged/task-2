# %%
email = "Amit_ml@gmail.edu"

if email.count("@") != 1 or "." not in email.split("@")[1]:
    print("Invalid email")
else:
    username = email.split("@")[0]
    domain = email.split("@")[1].rsplit(".", 1)[0]
    
    if email.endswith(".com"):
        domain_type = "Commercial Domain"
    elif email.endswith(".edu"):
        domain_type = "Educational Domain"
    else:
        domain_type = "Other Domain"
    
    print("Username:", username)
    print("Domain:", domain)
    print("Domain Type:", domain_type)
# Out:
# Username: Amit_ml
# Domain: gmail
# Domain Type: Educational Domain

# %%
msg = "###!!@mocleW PGTQ!!!6789"

core = msg.split("@")[1].split("!!!")[0].strip()
words = core.split()
words[0] = words[0][::-1]

print(words[0] + " " + words[1])
# Out:
# Welcom PGTQ

# %%
msg = "&&&**$gnirtS PLIO!!@1234"

core = msg.split("$")[1].split("!!")[0].strip()

words = core.split()
words[0] = words[0][::-1]
words[1] = words[1].replace("I", "E").replace("O", "U")

print(words[0] + " " + words[1])
# Out:
# String PLEU

# %%
msg = "##$$$@!yalpstcejorp EPUVT****9887"

core = msg.split("@!")[1].split("****")[0].strip()

words = core.split()
words[0] = words[0][::-1]
words[1] = words[1].replace("E", "A").replace("U", "O")

print(words[0] + " " + words[1])
# Out:
# projectsplay APOVT
